# %%
import pandas as pd
import numpy as np

# 1. Convert the CSV file to a pandas data frame
# Replace 'toxic_tweets.csv' with your local downloaded file path
df = pd.read_csv('NLP_Project/data/toxic_tweets.csv')

# Quick inspection
print("Dataset Shape:", df.shape)
print(df.head())

# Handle missing values if any
df['tweet'] = df['tweet'].fillna('') 
X = df['tweet']
y = df['target'] # Adjust column names based on the actual Kaggle schema
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 import numpy as np
#       4 # 1. Convert the CSV file to a pandas data frame
#       5 # Replace 'toxic_tweets.csv' with your local downloaded file path
# ----> 6 df = pd.read_csv('NLP_Project/data/toxic_tweets.csv')
#       8 # Quick inspection
#       9 print("Dataset Shape:", df.shape)
#
# ...
